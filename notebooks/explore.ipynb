# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_r = pd.read_csv("../data/realword_scores.csv")
df_r.columns = ["real", "word", "error"]
df_r["real"] = 1

df_f = pd.read_csv("../data/fakeword_scores.csv")
df_f.columns = ["real", "word", "error"]
df_f["real"] = 0

df = pd.concat([df_r, df_f], axis=0)

# %%
bins = np.linspace(0, 1, 50)
plt.hist(df_r["error"], bins, alpha=0.5, label='Real')
plt.hist(df_f["error"], bins, alpha=0.5, label='Fake')
plt.legend(loc='upper right')
plt.show()

# %%
df_f["error"].quantile(0.27)
# Out:
# 0.14564692437648774

# %%
df_f[df_f["error"] < 0.03]
# Out:
#       real  word     error
# 74       0  boed  0.027882
# 317      0  taba  0.026719
# 373      0  tyny  0.011272
# 420      0  miby  0.018860
# 457      0  tigo  0.025409
# 567      0  melo  0.026423
# 804      0  tany  0.022884
# 816      0  alzo  0.020754
# 2154     0  nals  0.025962
# 2185     0  dely  0.029444
# 2527     0  lumi  0.027150
# 2565     0  mezi  0.024571
# 2732     0  wyny  0.013929
# 2993     0  talu  0.026975
# 3038     0  lenk  0.028930
# 3437     0  lemo  0.026481
# 3866     0  lebs  0.029311
# 4655     0  teny  0.021934
# 5596     0  soln  0.029324
# 5745     0  tuly  0.029300
# 6249     0  wyed  0.017034
# 6488     0  wyld  0.019242
# 6689     0  nels  0.022462

# %%
df_r[df_r["error"] < 0.01]
# Out:
#       real  word     error
# 257      1  mare  0.008971
# 314      1  alma  0.006420
# 446      1  army  0.009055
# 489      1  mona  0.009835
# 1004     1  arms  0.005626
# 1400     1  thon  0.009656
# 1535     1  main  0.008643
# 1593     1  mank  0.009941
# 1594     1  mons  0.008630
# 1821     1  maga  0.009950
# 2000     1  mane  0.009245
# 2018     1  moot  0.009514
# 2093     1  mate  0.007907
# 2590     1  ales  0.004748
# 2614     1  alee  0.004092
# 2641     1  mabe  0.009502
# 2757     1  math  0.008854
# 2865     1  maha  0.008165
# 2928     1  mawn  0.007173
# 2989     1  alms  0.007954
# 3014     1  mads  0.009753
# 3247     1  maid  0.008693
# 3262     1  alea  0.008487
# 3293     1  moho  0.007828
# 3309     1  mala  0.008971
# 3507     1  mani  0.009992
# 3900     1  alle  0.004235
# 3950     1  mako  0.006516
# 4139     1  mull  0.009388
# 4232     1  maba  0.006675
# 4325     1  moys  0.006876
# 4485     1  mibs  0.009611
# 4498     1  ares  0.008271
# 4509     1  mawk  0.007248
# 4748     1  mats  0.007421
# 4884     1  maks  0.007536
# 4888     1  albs  0.008879
# 4993     1  alas  0.007006
# 5498     1  moon  0.009527
# 5525     1  maws  0.008113
# 5602     1  alar  0.009621
# 5910     1  make  0.009975
# 6203     1  ryes  0.009011
# 6290     1  moha  0.008467
# 6404     1  moyo  0.009644
# 6483     1  mall  0.007701
# 6504     1  slaw  0.009328
# 6628     1  mans  0.008597
# 6690     1  mars  0.006869
# 6700     1  mara  0.007857
# 6778     1  male  0.008633
# 6825     1  mabi  0.009887
# 7166     1  mono  0.009760
